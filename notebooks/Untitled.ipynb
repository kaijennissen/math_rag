# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles

# %%
from rag_chat.rag_chatbot import create_rag_chatbot

# %%
app=create_rag_chatbot()
# Out:
# 2024-09-19 20:56:58 - INFO - Found 1 PDF files
# Status: loaded, waiting for processing to complete
# 2024-09-19 20:57:05 - INFO - Loaded 1 documents
# 2024-09-19 20:57:05 - INFO - Split 1 documents into 5 chunks.

# %%
display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)
